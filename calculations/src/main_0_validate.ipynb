# %% [markdown]
# ### 0. Database Connection Setup
# Initializes the Ibis connection to the DuckDB database to load the fixed and yearly FAME tables.

# %%
import ibis
from ibis import _
from utils.f_0_dirs import get_data_dirs

dirs = get_data_dirs(segment="calculations")
con = ibis.duckdb.connect(dirs.db_path, read_only=True)

t_panel = con.table("fame_yearly_kp")
t_fixed = con.table("fame_fixed_filtered")
print("✅ Connected to database.")
# Out:
# ✅ Connected to database.

# %% [markdown]
# ### 1. Small Companies Exclusion
# Verify that no firm-year entries have fewer than 10 employees or missing employment data.

# %%
invalid_employees = t_panel.filter(
    _.employees.isnull() | (_.employees < 10)
).count().execute()

try:
    assert invalid_employees == 0, f"Found {invalid_employees:,} invalid employee entries."
    print("✅ Employee threshold test passed.")
except AssertionError as e:
    print(f"❌ Employee threshold test failed: {e}")
    sample_invalid = t_panel.filter(
        _.employees.isnull() | (_.employees < 10)
    ).sample(100 / invalid_employees).execute()
    display(sample_invalid)
# Out:
# ✅ Employee threshold test passed.

# %%
t_no_missing = t_panel.filter(
    (
        (_['remuneration_employees'].isnull() == False) &
        (_['ebitda'].isnull() == False)
    ) | (
        (_['profit_loss_pretax'].isnull() == False) &
        (_['interest_paid'].isnull() == False) &
        (_['depreciation'].isnull() == False) &
        (_['remuneration_employees'].isnull() == False)
    )
)
count_panel = t_panel.count().execute()
count_no_missing = t_no_missing.count().execute()
try:
    assert count_no_missing == count_panel, "There are missing values in the required columns."
    print("✅ No missing values in required columns.")
except AssertionError as e:
    print(f"❌ Missing values found: {e}")
    sample_missing = (
        t_panel.filter(
            (
                (_['remuneration_employees'].isnull() == True) |
                (_['ebitda'].isnull() == True) |
                (_['profit_loss_pretax'].isnull() == True) |
                (_['interest_paid'].isnull() == True) |
                (_['depreciation'].isnull() == True)
            )
        )
        .order_by(ibis.random())
        .limit(100)
        .execute()
    )
    display(sample_missing)
# Out:
# ✅ No missing values in required columns.

# %% [markdown]
# ### 2. UK Registered Numbers Only
# Verify that non-UK companies (e.g., prefixes '#', 'IE', 'GI') have been successfully dropped.

# %%
uk_prefixes = [
    '',   # England & Wales (pure numbers)
    'NI', # Northern Ireland Company (post-partition)
    'SC', # Scottish Company
    'OC', # Limited Liability Partnership - LLP (England & Wales)
    'SO', # Limited Liability Partnership - LLP (Scotland)
    'NC', # Limited Liability Partnership - LLP (Northern Ireland)
    'LP', # Limited Partnership (England & Wales)
    'SL', # Limited Partnership (Scotland)
    'ZC', # Unregistered Companies (Section 1043) for England & Wales
    'SZ', # Scottish Unregistered Companies (Section 1043)
    'SG', # Scottish Qualifying Partnership
    'CE', # Charitable Incorporated Organisation (England & Wales)
    'CS', # Scottish Charitable Incorporated Organisation
    'R',  # Older Northern Ireland company (no longer issued)
    'IP'  # Industrial and Provident Societies (cooperatives)
]
non_uk_prefixes = [
    'IE', # Ireland
    'JE', # Jersey
    'IM', # Isle of Man
    'GG', # Guernsey
    'GI', # Gibraltar,
    'SE'  # Société Européenne (European Company),
    '#',  # Foreign legal entites that are traded on LSEG
]

non_uk_regex = r'^(IE|JE|IM|GG|GI|SE|#)'

foreign_fixed = (
    t_fixed
    .mutate(
        first_2_str=_.registered_number.substr(0, 2),
        first_1_str=_.registered_number.substr(0, 1)
    )
    .select('registered_number', 'first_2_str', 'first_1_str')
    .filter((_.first_2_str.isin(non_uk_prefixes)) | (_.first_1_str == '#'))
)
count_foreign_fixed = foreign_fixed.count().execute()
foreign_yearly = (
    t_panel
    .mutate(
        first_2_str=_.registered_number.substr(0, 2),
        first_1_str=_.registered_number.substr(0, 1)
    )
    .select('registered_number', 'year', 'first_2_str', 'first_1_str')
    .filter((_.first_2_str.isin(non_uk_prefixes)) | (_.first_1_str == '#'))
)
count_foreign_yearly = foreign_yearly.count().execute()

try:
    assert count_foreign_fixed == 0, f"Found {count_foreign_fixed} foreign firm records."
    print("✅ UK-only test passed for fixed data.")
except AssertionError as e:
    print(f"❌ UK-only test failed for fixed data: {e}")
    sample_foreign_fixed = (
        foreign_fixed
        .order_by(ibis.random())
        .limit(100)
        .execute()
    )
    print(sample_foreign_fixed.to_csv())
try:
    assert count_foreign_yearly == 0, f"Found {count_foreign_yearly} foreign firm records."
    print("✅ UK-only test passed for yearly data.")
except AssertionError as e:
    print(f"❌ UK-only test failed for yearly data: {e}")
    sample_foreign_yearly = (
        foreign_yearly
        .order_by(ibis.random())
        .limit(10)
        .execute()
    )
    # Get the first value and 'extract' entry. Print its value and type
    first_row = sample_foreign_yearly.iloc[0]
    print(f"Extract entry: {first_row['extract']}, Type: {type(first_row['extract'])}")
    display(sample_foreign_yearly)
# Out:
# ✅ UK-only test passed for fixed data.
# ✅ UK-only test passed for yearly data.

# %% [markdown]
# ### 4. Duplicate Records Check
# Verify that each `registered_number` has strictly one record per `year` in the yearly panel.

# %%
duplicates = fame_yearly.group_by(['registered_number', 'year']) \
    .aggregate(row_count=fame_yearly.count()) \
    .filter(ibis._.row_count > 1).count().execute()

try:
    assert duplicates == 0, f"Found {duplicates} duplicate firm-year records."
    print("✅ Firm-year duplicate test passed.")
except AssertionError as e:
    print(f"❌ Firm-year duplicate test failed: {e}")
    sample_duplicates = fame_yearly.group_by(['registered_number', 'year']) \
        .aggregate(row_count=fame_yearly.count()) \
        .filter(ibis._.row_count > 1) \
        .sample(100 / duplicates).execute()
    display(sample_duplicates)
# Out:
# ✅ Firm-year duplicate test passed.

# %% [markdown]
# ### 5. Same Company Name Check
# Verify that no two separate `registered_number`s share the exact same `company_name`.

# %%
same_name = fame_fixed.group_by('company_name') \
    .aggregate(id_count=fame_fixed.registered_number.nunique()) \
    .filter(ibis._.id_count > 1).count().execute()

try:
    assert same_name == 0, f"Found {same_name} company names mapped to multiple registered numbers."
    print("✅ Shared company name test passed.")
except AssertionError as e:
    print(f"❌ Shared company name test failed: {e}")
    sample_same_name = fame_fixed.group_by('company_name') \
        .aggregate(id_count=fame_fixed.registered_number.nunique()) \
        .filter(ibis._.id_count > 1) \
        .inner_join(fame_fixed, ['company_name']) \
        .sample(100 / same_name if same_name >= 100 else 1).execute()
    display(sample_same_name)
# Out:
# ❌ Shared company name test failed: Found 68 company names mapped to multiple registered numbers.
#                    company_name  id_count registered_number ticker_symbol  \
# 0      PASSION HOLDINGS LIMITED         2          10418071           NaN
# 1     VALENTINO ENGLAND LIMITED         2          05895246           NaN
# 2          HWS HOLDINGS LIMITED         2          09745689           NaN
# 3    HOPKINS ARCHITECTS LIMITED         2          11779559           NaN
# 4        HARROGATE V.E. LIMITED         2          13861617           NaN
# ..                          ...       ...               ...           ...
# 133     ROYDON HOLDINGS LIMITED         2          03599085           NaN
# 134            LEONARDO LIMITED         2          05360430           NaN
# 135            VIANET GROUP PLC         2          05345684          VNET
# 136       CARE HOLDINGS LIMITED         2          06844795           NaN
# 137          BUILDSTORE LIMITED         2          08412572           NaN
#
#                                             ro_address  \
# 0                33-34 Rathbone Place, London, W1T 1JN
# 1                      16 Old Bailey, London, EC4M 7EG
# 2    Fourth Floor Abbots House, Abbey Street, Readi...
# 3                 27 Broadley Terrace, London, NW1 6LG
# 4    Vision Express, Ruddington Fields Business Par...
# ..                                                 ...
# 133  Units 1-3 Junction Eco Park, Rake Lane, Swinto...
# 134          Lysander Road, Yeovil, Somerset, BA20 2YB
# 135  1 Surtees Way, Surtees Business Park, Stockton...
# 136        2 The Calls, Leeds, West Yorkshire, LS2 7JU
# 137  Nsb & Rc Lydiard Fields, Great Western Way, Sw...
#
#                ro_address_line_1                ro_address_line_2  \
# 0           33-34 Rathbone Place                              NaN
# 1                  16 Old Bailey                              NaN
# 2      Fourth Floor Abbots House                     Abbey Street
# 3            27 Broadley Terrace                              NaN
# 4                 Vision Express  Ruddington Fields Business Park
# ..                           ...                              ...
# 133  Units 1-3 Junction Eco Park                        Rake Lane
# 134                Lysander Road                              NaN
# 135                1 Surtees Way            Surtees Business Park
# 136                  2 The Calls                              NaN
# 137      Nsb & Rc Lydiard Fields                Great Western Way
#
#     ro_address_line_3 ro_address_line_4 ro_address_line_5  ...  \
# 0                 NaN               NaN               NaN  ...
# 1                 NaN               NaN               NaN  ...
# 2                 NaN               NaN               NaN  ...
# 3                 NaN               NaN               NaN  ...
# 4          Ruddington               NaN               NaN  ...
# ..                ...               ...               ...  ...
# 133           Swinton               NaN               NaN  ...
# 134               NaN               NaN               NaN  ...
# 135               NaN               NaN               NaN  ...
# 136               NaN               NaN               NaN  ...
# 137               NaN               NaN               NaN  ...
#
#                     branch_name primary_uk_sic_2007_code  \
# 0      PASSION HOLDINGS LIMITED                    59113
# 1     VALENTINO ENGLAND LIMITED                    82990
# 2                           NaN                    82990
# 3    HOPKINS ARCHITECTS LIMITED                    71111
# 4        HARROGATE V.E. LIMITED                    96090
# ..                          ...                      ...
# 133     ROYDON HOLDINGS LIMITED                    20160
# 134            LEONARDO LIMITED                    70100
# 135            VIANET GROUP PLC                    96090
# 136       CARE HOLDINGS LIMITED                    87900
# 137          BUILDSTORE LIMITED                    70100
#
#                       primary_uk_sic_2007_description latest_accounts_date  \
# 0          Television programme production activities           2024-03-31
# 1    Other business support service activities n.e.c.           2013-12-31
# 2    Other business support service activities n.e.c.           2023-12-31
# 3                            Architectural activities           2024-03-31
# 4            Other personal service activities n.e.c.           2023-12-31
# ..                                                ...                  ...
# 133          Manufacture of plastics in primary forms           2012-10-31
# 134                        Activities of head offices           2023-12-31
# 135          Other personal service activities n.e.c.           2024-03-31
# 136                 Other residential care activities           2023-12-31
# 137                        Activities of head offices           2023-12-31
#
#     no_of_available_years                                          guo guo_nb  \
# 0                       7                           MRS MARIE RUHEMANN   39.0
# 1                       7                                          NaN    0.0
# 2                       9                         TIDE UK HOLDINGS LLC    8.0
# 3                       6  HOPKINS ARCHITECTS EMPLOYEE TRUSTEE LIMITED    2.0
# 4                       2                             ESSILORLUXOTTICA  994.0
# ..                    ...                                          ...    ...
# 133                    14                                          NaN    0.0
# 134                    19                              LEONARDO S.P.A.  340.0
# 135                    19                             VIANET GROUP PLC    7.0
# 136                    15                                          NaN    NaN
# 137                    11                           BUILDSTORE LIMITED   17.0
#
#           entity_type industry_codes   file_codes
# 0    Controlled subs.             59        18_17
# 1     Single location             82        10_05
# 2    Controlled subs.             82        10_30
# 3    Controlled subs.             71        18_27
# 4    Controlled subs.             96        17_32
# ..                ...            ...          ...
# 133   Single location             20        22_11
# 134  Controlled subs.             70      16_57 1
# 135               GUO             96        17_32
# 136               NaN          64,87  12_48,19_22
# 137               GUO             70      16_59 2
#
# [138 rows x 32 columns]

# %% [markdown]
# ### 6. Subsidiaries Check
# Verify that no firm in the dataset is a subsidiary of another firm in the dataset (matching `guo` to `company_name`).

# %%
t1 = fame_fixed.alias('t1')
t2 = fame_fixed.alias('t2')

subsidiaries = t1.inner_join(
    t2, t1.guo == t2.company_name
).filter(t1.registered_number != t2.registered_number).count().execute()

assert subsidiaries == 0, f"Found {subsidiaries} firms that are subsidiaries of others in the dataset."
print("✅ Subsidiaries exclusion test passed.")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 8
#       2 t2 = fame_fixed.alias('t2')
#       4 subsidiaries = t1.inner_join(
#       5     t2, t1.guo == t2.company_name
#       6 ).filter(t1.registered_number != t2.registered_number).count().execute()
# ----> 8 assert subsidiaries == 0, f"Found {subsidiaries} firms that are subsidiaries of others in the dataset."
#       9 print("✅ Subsidiaries exclusion test passed.")
#
# AssertionError: Found 17630 firms that are subsidiaries of others in the dataset.

# %% [markdown]
# ### 7. Account Balancing Check
# Verify the core accounting identity: Total Assets must equal Liabilities + Shareholders' Funds (allowing £2,000 margin of error).

# %%
imbalance = fame_yearly.filter(
    abs(fame_yearly.total_assets - (fame_yearly.liabilities + fame_yearly.shareholders_funds)) > 2000
).count().execute()

assert imbalance == 0, f"Found {imbalance} rows failing the account balancing check."
print("✅ Account balancing test passed.")

# %% [markdown]
# ### 8. Outlier Validation (Flagged but Kept)
# Verify that negative assets are dropped, but extreme values (negative turnover, high turnover/assets) exist and are handled gracefully.

# %%
negative_assets = fame_yearly.filter(fame_yearly.total_assets < 0).count().execute()
assert negative_assets == 0, "Negative total assets were not properly dropped."

negative_turnover = fame_yearly.filter(fame_yearly.turnover < 0).count().execute()
high_ratio = fame_yearly.filter((fame_yearly.turnover / fame_yearly.total_assets) > 50).count().execute()

print("✅ Negative assets properly dropped.")
print(f"ℹ️ Validated retention of negative turnover rows: {negative_turnover}")
print(f"ℹ️ Validated retention of high turnover/assets rows: {high_ratio}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 negative_assets = fame_yearly.filter(fame_yearly.total_assets < 0).count().execute()
# ----> 2 assert negative_assets == 0, "Negative total assets were not properly dropped."
#       4 negative_turnover = fame_yearly.filter(fame_yearly.turnover < 0).count().execute()
#       5 high_ratio = fame_yearly.filter((fame_yearly.turnover / fame_yearly.total_assets) > 50).count().execute()
#
# AssertionError: Negative total assets were not properly dropped.

# %% [markdown]
# ### 9. Deflation Check (Conceptual)
# Verify that the yearly monetary columns are typed correctly as floats, indicating successful execution of the deflation pipeline.

# %%
assert fame_yearly.turnover.type().is_float64(), "Turnover is not correctly typed as a deflated float."
assert fame_yearly.wages.type().is_float64(), "Wages is not correctly typed as a deflated float."

print("✅ Deflation structural check passed.")
