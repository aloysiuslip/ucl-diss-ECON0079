# %%
import re

# Import build/logs/main-loop2.log
log_text = ""
with open("../logs/main-loop2.log", "r", encoding="utf-8") as f:
    # Read the entire log file into a string, ensuring proper encoding
    log_text = f.read()

industries = re.findall(r"Successfully appended .*? from: (\d{2})", log_text)
ind_set = set(industries)
ordered_set = sorted(ind_set, key=lambda x: int(x))
print(len(ind_set))
print(ordered_set)
# After 96m 50s
# Out:
# 76
# ['01', '02', '03', '05', '06', '07', '08', '10', '12', '13', '15', '17', '18', '19', '21', '22', '23', '24', '25', '26', '27', '28', '30', '31', '32', '33', '35', '37', '38', '39', '41', '42', '45', '46', '49', '50', '51', '52', '53', '55', '56', '58', '59', '60', '61', '62', '63', '64', '65', '68', '69', '70', '71', '72', '75', '77', '78', '79', '80', '81', '82', '84', '85', '86', '87', '88', '90', '91', '92', '93', '94', '95', '96', '97', '98', '99']
